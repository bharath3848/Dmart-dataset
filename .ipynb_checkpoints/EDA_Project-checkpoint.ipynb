# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dmart.csv")
df
# Out:
#                                            Name    Brand   Price  \
# 0                        Premia Badam (Almonds)   Premia   451.0
# 1                        Premia Badam (Almonds)   Premia   109.0
# 2                        Premia Badam (Almonds)   Premia   202.0
# 3             Nutraj California Almonds (Badam)   Nutraj   599.0
# 4             Nutraj California Almonds (Badam)   Nutraj  1549.0
# ...                                         ...      ...     ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet    55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet    85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet    55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet   110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet    90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# 1                85.0          Grocery  Grocery/Dry Fruits   100 gm
# 2               175.0          Grocery  Grocery/Dry Fruits   200 gm
# 3               349.0          Grocery          Dry Fruits   500 gm
# 4               659.0          Grocery          Dry Fruits     1 kg
# ...               ...              ...                 ...      ...
# 5184             36.0  School Supplies        School Needs   1 Book
# 5185             69.0  School Supplies        School Needs   1 Book
# 5186             40.0  School Supplies        School Needs   1 Book
# 5187             72.0  School Supplies        School Needs   1 Book
# 5188             75.0  School Supplies        School Needs      1 U
#
#                                             Description  \
# 0                                                 India
# 1                                                 India
# 2                                                 India
# 3                                                   USA
# 4                                                   USA
# ...                                                 ...
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# 5186  OverviewAttractive colour and designs. Easy to...
# 5187  OverviewDrawing book has attractive cover desi...
# 5188  OverviewCoated with a double layer of acrylic ...
#
#                          BreadCrumbs
# 0       Grocery > Grocery/Dry Fruits
# 1       Grocery > Grocery/Dry Fruits
# 2       Grocery > Grocery/Dry Fruits
# 3               Grocery > Dry Fruits
# 4               Grocery > Dry Fruits
# ...                              ...
# 5184  School Supplies > School Needs
# 5185  School Supplies > School Needs
# 5186  School Supplies > School Needs
# 5187  School Supplies > School Needs
# 5188  School Supplies > School Needs
#
# [5189 rows x 9 columns]

# %%
df.head()
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity Description  \
# 0  Grocery  Grocery/Dry Fruits   500 gm       India
# 1  Grocery  Grocery/Dry Fruits   100 gm       India
# 2  Grocery  Grocery/Dry Fruits   200 gm       India
# 3  Grocery          Dry Fruits   500 gm         USA
# 4  Grocery          Dry Fruits     1 kg         USA
#
#                     BreadCrumbs
# 0  Grocery > Grocery/Dry Fruits
# 1  Grocery > Grocery/Dry Fruits
# 2  Grocery > Grocery/Dry Fruits
# 3          Grocery > Dry Fruits
# 4          Grocery > Dry Fruits

# %%
df.tail()
# Out:
#                                            Name    Brand  Price  \
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet   55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet   85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet   55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet  110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet   90.0
#
#       DiscountedPrice         Category   SubCategory Quantity  \
# 5184             36.0  School Supplies  School Needs   1 Book
# 5185             69.0  School Supplies  School Needs   1 Book
# 5186             40.0  School Supplies  School Needs   1 Book
# 5187             72.0  School Supplies  School Needs   1 Book
# 5188             75.0  School Supplies  School Needs      1 U
#
#                                             Description  \
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# 5186  OverviewAttractive colour and designs. Easy to...
# 5187  OverviewDrawing book has attractive cover desi...
# 5188  OverviewCoated with a double layer of acrylic ...
#
#                          BreadCrumbs
# 5184  School Supplies > School Needs
# 5185  School Supplies > School Needs
# 5186  School Supplies > School Needs
# 5187  School Supplies > School Needs
# 5188  School Supplies > School Needs

# %%
df.columns
# Out:
# Index(['Name', 'Brand', 'Price', 'DiscountedPrice', 'Category', 'SubCategory',
#        'Quantity', 'Description', 'BreadCrumbs'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5188 non-null   object
#  1   Brand            4789 non-null   object
#  2   Price            5188 non-null   float64
#  3   DiscountedPrice  5188 non-null   float64
#  4   Category         5186 non-null   object
#  5   SubCategory      5186 non-null   object
#  6   Quantity         5188 non-null   object
#  7   Description      5187 non-null   object
#  8   BreadCrumbs      5186 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 365.0+ KB

# %%
df.describe()
# Out:
#               Price  DiscountedPrice
# count   5188.000000      5188.000000
# mean     344.030360       236.669719
# std      601.034092       387.198716
# min        0.000000         0.000000
# 25%       85.000000        64.000000
# 50%      175.000000       125.000000
# 75%      345.000000       249.000000
# max    10990.000000      7999.000000

# %%
df.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                1
# DiscountedPrice      1
# Category             3
# SubCategory          3
# Quantity             1
# Description          2
# BreadCrumbs          3
# dtype: int64

# %%
df.shape
# Out:
# (5189, 9)

# %%
df['Brand'] = df['Brand'].fillna('others')

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Name               0
# Brand              0
# Price              0
# DiscountedPrice    0
# Category           0
# SubCategory        0
# Quantity           0
# Description        0
# BreadCrumbs        0
# dtype: int64

# %%
sns.boxplot(df['Price'])
plt.show()
# Out:
# C:\Users\bhara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['DiscountedPrice'])
plt.show()
# Out:
# C:\Users\bhara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Price'].quantile([0.5,0.67,0.79,0.95,0.99])
# Out:
# 0.50     175.00
# 0.67     266.00
# 0.79     399.00
# 0.95    1249.00
# 0.99    3104.75
# Name: Price, dtype: float64

# %%
df['Price'].max()
# Out:
# 10990.0

# %%
df['DiscountedPrice'].quantile([0.5,0.67,0.79,0.95,0.99])
# Out:
# 0.50     125.00
# 0.67     195.00
# 0.79     284.99
# 0.95     849.00
# 0.99    2020.43
# Name: DiscountedPrice, dtype: float64

# %%
df['DiscountedPrice'].describe()
# Out:
# count    5182.000000
# mean      235.959572
# std       386.141033
# min         0.000000
# 25%        64.000000
# 50%       125.000000
# 75%       249.000000
# max      7999.000000
# Name: DiscountedPrice, dtype: float64

# %%
Q1=df['Price'].quantile(0.25)
Q3=df['Price'].quantile(0.75)
Q1,Q3
# Out:
# (85.0, 345.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 260.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (-305.0, 735.0)

# %%
df_no = df[(df['Price'] > lower_limit) & (df['Price'] < upper_limit)]
df_no
# Out:
#                                            Name    Brand  Price  \
# 0                        Premia Badam (Almonds)   Premia  451.0
# 1                        Premia Badam (Almonds)   Premia  109.0
# 2                        Premia Badam (Almonds)   Premia  202.0
# 3             Nutraj California Almonds (Badam)   Nutraj  599.0
# 5                                     Chana Dal   others   49.0
# ...                                         ...      ...    ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet   55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet   85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet   55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet  110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet   90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# 1                85.0          Grocery  Grocery/Dry Fruits   100 gm
# 2               175.0          Grocery  Grocery/Dry Fruits   200 gm
# 3               349.0          Grocery          Dry Fruits   500 gm
# 5                42.0          Grocery                Dals   500 gm
# ...               ...              ...                 ...      ...
# 5184             36.0  School Supplies        School Needs   1 Book
# 5185             69.0  School Supplies        School Needs   1 Book
# 5186             40.0  School Supplies        School Needs   1 Book
# 5187             72.0  School Supplies        School Needs   1 Book
# 5188             75.0  School Supplies        School Needs      1 U
#
#                                             Description  \
# 0                                                 India
# 1                                                 India
# 2                                                 India
# 3                                                   USA
# 5                                                 India
# ...                                                 ...
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# 5186  OverviewAttractive colour and designs. Easy to...
# 5187  OverviewDrawing book has attractive cover desi...
# 5188  OverviewCoated with a double layer of acrylic ...
#
#                          BreadCrumbs
# 0       Grocery > Grocery/Dry Fruits
# 1       Grocery > Grocery/Dry Fruits
# 2       Grocery > Grocery/Dry Fruits
# 3               Grocery > Dry Fruits
# 5                     Grocery > Dals
# ...                              ...
# 5184  School Supplies > School Needs
# 5185  School Supplies > School Needs
# 5186  School Supplies > School Needs
# 5187  School Supplies > School Needs
# 5188  School Supplies > School Needs
#
# [4730 rows x 9 columns]

# %%
Q1=df['DiscountedPrice'].quantile(0.25)
Q3=df['DiscountedPrice'].quantile(0.75)
Q1,Q3
# Out:
# (64.0, 249.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 185.0

# %%
lower_limit1 = Q1 - 1.5*IQR
upper_limit1 = Q3 + 1.5*IQR
lower_limit1,upper_limit1
# Out:
# (-213.5, 526.5)

# %%
df_no_1 = df[(df['DiscountedPrice'] > lower_limit) & (df['DiscountedPrice'] < upper_limit)]
df_no_1
# Out:
#                                            Name    Brand   Price  \
# 0                        Premia Badam (Almonds)   Premia   451.0
# 1                        Premia Badam (Almonds)   Premia   109.0
# 2                        Premia Badam (Almonds)   Premia   202.0
# 3             Nutraj California Almonds (Badam)   Nutraj   599.0
# 4             Nutraj California Almonds (Badam)   Nutraj  1549.0
# ...                                         ...      ...     ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet    55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet    85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet    55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet   110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet    90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# 1                85.0          Grocery  Grocery/Dry Fruits   100 gm
# 2               175.0          Grocery  Grocery/Dry Fruits   200 gm
# 3               349.0          Grocery          Dry Fruits   500 gm
# 4               659.0          Grocery          Dry Fruits     1 kg
# ...               ...              ...                 ...      ...
# 5184             36.0  School Supplies        School Needs   1 Book
# 5185             69.0  School Supplies        School Needs   1 Book
# 5186             40.0  School Supplies        School Needs   1 Book
# 5187             72.0  School Supplies        School Needs   1 Book
# 5188             75.0  School Supplies        School Needs      1 U
#
#                                             Description  \
# 0                                                 India
# 1                                                 India
# 2                                                 India
# 3                                                   USA
# 4                                                   USA
# ...                                                 ...
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# 5186  OverviewAttractive colour and designs. Easy to...
# 5187  OverviewDrawing book has attractive cover desi...
# 5188  OverviewCoated with a double layer of acrylic ...
#
#                          BreadCrumbs
# 0       Grocery > Grocery/Dry Fruits
# 1       Grocery > Grocery/Dry Fruits
# 2       Grocery > Grocery/Dry Fruits
# 3               Grocery > Dry Fruits
# 4               Grocery > Dry Fruits
# ...                              ...
# 5184  School Supplies > School Needs
# 5185  School Supplies > School Needs
# 5186  School Supplies > School Needs
# 5187  School Supplies > School Needs
# 5188  School Supplies > School Needs
#
# [4877 rows x 9 columns]

# %%
sns.boxplot(df_no['Price'])
plt.show()
# Out:
# C:\Users\bhara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df_no_1['DiscountedPrice'])
plt.show()
# Out:
# C:\Users\bhara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Category'].value_counts(normalize=True).plot.barh(figsize=[10,7])
plt.show()

# %%
df['SubCategory'].value_counts(normalize=True).plot.barh(figsize=[10,15])
plt.show()

# %%
df['Brand'].value_counts().head(10).plot.bar()
plt.show()

# %%
plt.scatter(df['Price'],df['DiscountedPrice'])
plt.show()

# %%
df.plot.scatter(x='Quantity',y='Price')
plt.show()

# %%
sns.pairplot(data=df,vars = ['Category','Price','DiscountedPrice'])

# %%
sns.pairplot(df,hue ='Category')

# %%
sns.heatmap(df[['Price','DiscountedPrice']].corr(),annot= True,cmap='Reds')
plt.show()

# %%
df.groupby('Brand')['Price'].mean()
# Out:
# Brand
# 24 Mantra             260.000000
# 24 Mantra Organic     120.800000
# 4700 BC                69.166667
# 4700 BC Popcorn        77.500000
# 7 Up                   99.000000
#                         ...
# Zandu                 235.000000
# Zebronics            1065.428571
# Zeel                  929.187500
# others                240.273183
# pampers               249.000000
# Name: Price, Length: 823, dtype: float64

# %%
sns.boxplot(data=df,x='Brand',y='Price')
plt.show()
# Out:
# C:\Users\bhara\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\bhara\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
res = pd.pivot_table(data=df,index = 'Category',columns='Quantity',values='Price')
res
# Out:
# Quantity                         1 L        5 kg   50 gm   5x125 gm   6 Pcs  \
# Category
# Appliances                       NaN         NaN     NaN        NaN     NaN
# Baby & Kids                      NaN         NaN     NaN        NaN     NaN
# Backpacks                        NaN         NaN     NaN        NaN     NaN
# Beauty & Cosmetics               NaN         NaN     NaN        NaN     NaN
# Butterfly                        NaN         NaN     NaN        NaN     NaN
# Clothing & Accessories           NaN         NaN     NaN        NaN     NaN
# Computer Accessories             NaN         NaN     NaN        NaN     NaN
# DMart Grocery                    NaN  406.666667     NaN        NaN     NaN
# Dairy & Beverages                NaN         NaN     NaN        NaN     NaN
# Fruits & Vegetables              NaN         NaN     NaN        NaN     NaN
# Geep                             NaN         NaN     NaN        NaN     NaN
# Grocery                          NaN         NaN    43.0        NaN     NaN
# Home & Kitchen                 155.0         NaN     NaN        NaN   597.0
# Joyo Plastics                    NaN         NaN     NaN        NaN     NaN
# Kitchen Aprons                   NaN         NaN     NaN        NaN     NaN
# Motorbike Helmets                NaN         NaN     NaN        NaN     NaN
# Packaged Food                    NaN         NaN     NaN        NaN     NaN
# Personal Care                    NaN         NaN     NaN      270.0     NaN
# Pigeon                           NaN         NaN     NaN        NaN     NaN
# Plant Container                  NaN         NaN     NaN        NaN     NaN
# Raincoat                         NaN         NaN     NaN        NaN     NaN
# School Supplies                  NaN         NaN     NaN        NaN     NaN
# Smartwatches                     NaN         NaN     NaN        NaN     NaN
# Specials                         NaN         NaN     NaN        NaN     NaN
# Syska                            NaN         NaN     NaN        NaN     NaN
# Tableware                        NaN         NaN     NaN        NaN     NaN
# Water Purifiers & Accessories    NaN         NaN     NaN        NaN     NaN
# Wonderchef                       NaN         NaN     NaN        NaN     NaN
# Zebronics                        NaN         NaN     NaN        NaN     NaN
#
# Quantity                          0.35 gm  0.5 Watts  0.6 ml  0.7 gm  \
# Category
# Appliances                            NaN        NaN     NaN     NaN
# Baby & Kids                           NaN        NaN     NaN     NaN
# Backpacks                             NaN        NaN     NaN     NaN
# Beauty & Cosmetics                    NaN        NaN     NaN     NaN
# Butterfly                             NaN        NaN     NaN     NaN
# Clothing & Accessories                NaN        NaN     NaN     NaN
# Computer Accessories                  NaN        NaN     NaN     NaN
# DMart Grocery                         NaN        NaN     NaN     NaN
# Dairy & Beverages                     NaN        NaN     NaN     NaN
# Fruits & Vegetables                   NaN        NaN     NaN     NaN
# Geep                                  NaN        NaN     NaN     NaN
# Grocery                               NaN        NaN     NaN     NaN
# Home & Kitchen                        NaN        NaN     NaN     NaN
# Joyo Plastics                         NaN        NaN     NaN     NaN
# Kitchen Aprons                        NaN        NaN     NaN     NaN
# Motorbike Helmets                     NaN        NaN     NaN     NaN
# Packaged Food                         NaN        NaN     NaN     NaN
# Personal Care                  234.428571        NaN   399.0   330.0
# Pigeon                                NaN        NaN     NaN     NaN
# Plant Container                       NaN        NaN     NaN     NaN
# Raincoat                              NaN        NaN     NaN     NaN
# School Supplies                       NaN        NaN     NaN     NaN
# Smartwatches                          NaN        NaN     NaN     NaN
# Specials                              NaN      120.0     NaN     NaN
# Syska                                 NaN        NaN     NaN     NaN
# Tableware                             NaN        NaN     NaN     NaN
# Water Purifiers & Accessories         NaN        NaN     NaN     NaN
# Wonderchef                            NaN        NaN     NaN     NaN
# Zebronics                             NaN        NaN     NaN     NaN
#
# Quantity                           1 Book  ...  Smoked Brown  Steel  \
# Category                                   ...
# Appliances                            NaN  ...        2430.0    NaN
# Baby & Kids                           NaN  ...           NaN    NaN
# Backpacks                             NaN  ...           NaN    NaN
# Beauty & Cosmetics                    NaN  ...           NaN    NaN
# Butterfly                             NaN  ...           NaN    NaN
# Clothing & Accessories                NaN  ...           NaN    NaN
# Computer Accessories                  NaN  ...           NaN    NaN
# DMart Grocery                         NaN  ...           NaN    NaN
# Dairy & Beverages                     NaN  ...           NaN    NaN
# Fruits & Vegetables                   NaN  ...           NaN    NaN
# Geep                                  NaN  ...           NaN    NaN
# Grocery                               NaN  ...           NaN    NaN
# Home & Kitchen                        NaN  ...           NaN  242.5
# Joyo Plastics                         NaN  ...           NaN    NaN
# Kitchen Aprons                        NaN  ...           NaN    NaN
# Motorbike Helmets                     NaN  ...           NaN    NaN
# Packaged Food                         NaN  ...           NaN    NaN
# Personal Care                         NaN  ...           NaN    NaN
# Pigeon                                NaN  ...           NaN    NaN
# Plant Container                       NaN  ...           NaN    NaN
# Raincoat                              NaN  ...           NaN    NaN
# School Supplies                101.526316  ...           NaN    NaN
# Smartwatches                          NaN  ...           NaN    NaN
# Specials                              NaN  ...           NaN    NaN
# Syska                                 NaN  ...           NaN    NaN
# Tableware                             NaN  ...           NaN    NaN
# Water Purifiers & Accessories         NaN  ...           NaN    NaN
# Wonderchef                            NaN  ...           NaN    NaN
# Zebronics                             NaN  ...           NaN    NaN
#
# Quantity                       Strike Brown  Strike Mauve  Trinity Green  \
# Category
# Appliances                              NaN           NaN            NaN
# Baby & Kids                             NaN           NaN            NaN
# Backpacks                               NaN           NaN            NaN
# Beauty & Cosmetics                      NaN           NaN            NaN
# Butterfly                               NaN           NaN            NaN
# Clothing & Accessories                  NaN           NaN            NaN
# Computer Accessories                    NaN           NaN            NaN
# DMart Grocery                           NaN           NaN            NaN
# Dairy & Beverages                       NaN           NaN            NaN
# Fruits & Vegetables                     NaN           NaN            NaN
# Geep                                    NaN           NaN            NaN
# Grocery                                 NaN           NaN            NaN
# Home & Kitchen                       1799.0        1799.0            NaN
# Joyo Plastics                           NaN           NaN            NaN
# Kitchen Aprons                          NaN           NaN            NaN
# Motorbike Helmets                       NaN           NaN            NaN
# Packaged Food                           NaN           NaN            NaN
# Personal Care                           NaN           NaN            NaN
# Pigeon                                  NaN           NaN            NaN
# Plant Container                         NaN           NaN            NaN
# Raincoat                                NaN           NaN            NaN
# School Supplies                         NaN           NaN            NaN
# Smartwatches                            NaN           NaN            NaN
# Specials                                NaN           NaN         1825.0
# Syska                                   NaN           NaN            NaN
# Tableware                               NaN           NaN            NaN
# Water Purifiers & Accessories           NaN           NaN            NaN
# Wonderchef                              NaN           NaN            NaN
# Zebronics                               NaN           NaN            NaN
#
# Quantity                       XL (95 cm)  XXL (100 cm)  XXXL (105 cm)  \
# Category
# Appliances                            NaN           NaN            NaN
# Baby & Kids                           NaN           NaN            NaN
# Backpacks                             NaN           NaN            NaN
# Beauty & Cosmetics                    NaN           NaN            NaN
# Butterfly                             NaN           NaN            NaN
# Clothing & Accessories              450.0         475.0          500.0
# Computer Accessories                  NaN           NaN            NaN
# DMart Grocery                         NaN           NaN            NaN
# Dairy & Beverages                     NaN           NaN            NaN
# Fruits & Vegetables                   NaN           NaN            NaN
# Geep                                  NaN           NaN            NaN
# Grocery                               NaN           NaN            NaN
# Home & Kitchen                        NaN           NaN            NaN
# Joyo Plastics                         NaN           NaN            NaN
# Kitchen Aprons                        NaN           NaN            NaN
# Motorbike Helmets                     NaN           NaN            NaN
# Packaged Food                         NaN           NaN            NaN
# Personal Care                         NaN           NaN            NaN
# Pigeon                                NaN           NaN            NaN
# Plant Container                       NaN           NaN            NaN
# Raincoat                              NaN           NaN            NaN
# School Supplies                       NaN           NaN            NaN
# Smartwatches                          NaN           NaN            NaN
# Specials                              NaN           NaN            NaN
# Syska                                 NaN           NaN            NaN
# Tableware                             NaN           NaN            NaN
# Water Purifiers & Accessories         NaN           NaN            NaN
# Wonderchef                            NaN           NaN            NaN
# Zebronics                             NaN           NaN            NaN
#
# Quantity                       ZOE Peri  Zoe Pink
# Category
# Appliances                          NaN       NaN
# Baby & Kids                         NaN       NaN
# Backpacks                           NaN       NaN
# Beauty & Cosmetics                  NaN       NaN
# Butterfly                           NaN       NaN
# Clothing & Accessories              NaN       NaN
# Computer Accessories                NaN       NaN
# DMart Grocery                       NaN       NaN
# Dairy & Beverages                   NaN       NaN
# Fruits & Vegetables                 NaN       NaN
# Geep                                NaN       NaN
# Grocery                             NaN       NaN
# Home & Kitchen                   1799.0    1799.0
# Joyo Plastics                       NaN       NaN
# Kitchen Aprons                      NaN       NaN
# Motorbike Helmets                   NaN       NaN
# Packaged Food                       NaN       NaN
# Personal Care                       NaN       NaN
# Pigeon                              NaN       NaN
# Plant Container                     NaN       NaN
# Raincoat                            NaN       NaN
# School Supplies                     NaN       NaN
# Smartwatches                        NaN       NaN
# Specials                            NaN       NaN
# Syska                               NaN       NaN
# Tableware                           NaN       NaN
# Water Purifiers & Accessories       NaN       NaN
# Wonderchef                          NaN       NaN
# Zebronics                           NaN       NaN
#
# [29 rows x 631 columns]

# %%
sns.heatmap(data=res,annot=True)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Category'>
