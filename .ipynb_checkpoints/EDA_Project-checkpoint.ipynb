# %% [markdown]
#  <h1><center><font color='Red'>Dmart Products</font></center></h1>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd                           # We imported pandas as pd
import numpy as np                            # We imported numpy as np
import matplotlib.pyplot as plt               # We imported matplotlib as plt
import seaborn as sns                         # We imported seaborn as sns
import warnings                               # We imported warnings to avoid unnecessary warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Pandas
#
# ### Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,built on top of the Python programming language.

# %% [markdown]
# ## Numpy
#
# ### NumPy is a Python library used for working with arrays.
# ### It also has functions for working in domain of linear algebra, fourier transform, and matrices.

# %% [markdown]
# ## Matplotlib
#
# ### Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %% [markdown]
# ## Seaborn
#
# ### Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %% [markdown]
# ## Warnings
#
# ### Warning messages are typically issued in situations where it is useful to alert the user of some condition in a program, where that condition (normally) doesn’t warrant raising an exception and terminating the program.

# %% [markdown]
# # Visualizing dataset

# %%
df = pd.read_csv("Dmart.csv")         #To visualize the dataset pd.read is used
df
# Out:
#                                            Name    Brand   Price  \
# 0                        Premia Badam (Almonds)   Premia   451.0
# 1                        Premia Badam (Almonds)   Premia   109.0
# 2                        Premia Badam (Almonds)   Premia   202.0
# 3             Nutraj California Almonds (Badam)   Nutraj   599.0
# 4             Nutraj California Almonds (Badam)   Nutraj  1549.0
# ...                                         ...      ...     ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet    55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet    85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet    55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet   110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet    90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# ...

# %%
df.head()           # df.head gives us the top 5 rows of a dataset
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity Description  \
# 0  Grocery  Grocery/Dry Fruits   500 gm       India
# 1  Grocery  Grocery/Dry Fruits   100 gm       India
# 2  Grocery  Grocery/Dry Fruits   200 gm       India
# 3  Grocery          Dry Fruits   500 gm         USA
# 4  Grocery          Dry Fruits     1 kg         USA
#
#                     BreadCrumbs
# 0  Grocery > Grocery/Dry Fruits
# 1  Grocery > Grocery/Dry Fruits
# 2  Grocery > Grocery/Dry Fruits
# 3          Grocery > Dry Fruits
# 4          Grocery > Dry Fruits

# %%
df.tail()          # df.tail gives us the last 5 rows of a dataset
# Out:
#                                            Name    Brand  Price  \
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet   55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet   85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet   55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet  110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet   90.0
#
#       DiscountedPrice         Category   SubCategory Quantity  \
# 5184             36.0  School Supplies  School Needs   1 Book
# 5185             69.0  School Supplies  School Needs   1 Book
# 5186             40.0  School Supplies  School Needs   1 Book
# 5187             72.0  School Supplies  School Needs   1 Book
# 5188             75.0  School Supplies  School Needs      1 U
#
#                                             Description  \
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# ...

# %%
df.columns        # df.columns gives us the names of all the columns of the dataset
# Out:
# Index(['Name', 'Brand', 'Price', 'DiscountedPrice', 'Category', 'SubCategory',
#        'Quantity', 'Description', 'BreadCrumbs'],
#       dtype='object')

# %%
df.info()        # df.info gives us the data types,number of values in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5188 non-null   object
#  1   Brand            4789 non-null   object
#  2   Price            5188 non-null   float64
#  3   DiscountedPrice  5188 non-null   float64
#  4   Category         5186 non-null   object
#  5   SubCategory      5186 non-null   object
#  6   Quantity         5188 non-null   object
#  7   Description      5187 non-null   object
#  8   BreadCrumbs      5186 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 365.0+ KB

# %% [markdown]
# ### We can see there are only two numerical columns and remaining are categorical columns.

# %%
df.describe()         # df.describe gives us the statistical information like mean,count,max,percentiles of integeral datatypes.
# Out:
#               Price  DiscountedPrice
# count   5188.000000      5188.000000
# mean     344.030360       236.669719
# std      601.034092       387.198716
# min        0.000000         0.000000
# 25%       85.000000        64.000000
# 50%      175.000000       125.000000
# 75%      345.000000       249.000000
# max    10990.000000      7999.000000

# %% [markdown]
# ### We can see the mean,standard deviation of price column is greater than mean,standard deviation of discounted price column.
#
# ### There is huge difference between 75 percentile and maximum values of the numerical columns.

# %% [markdown]
# ## Treating Missing Values

# %% [markdown]
# ### In statistics missing data, or missing values, occur when no data value is stored for the variable in an observation.

# %%
df.isnull().sum()        # df.isnull.sum gives the count of all missing values in each column
# Out:
# Name                 1
# Brand              400
# Price                1
# DiscountedPrice      1
# Category             3
# SubCategory          3
# Quantity             1
# Description          2
# BreadCrumbs          3
# dtype: int64

# %% [markdown]
# ### There are 400 null values in  the brand column and very few null values in the remaining columns.

# %%
df.shape                 # df.shape gives us the number of columns and rows in a dataset
# Out:
# (5189, 9)

# %%
df['Brand'] = df['Brand'].fillna('others')       # df.fillna fills the missing values by mean,mode,median or anyother values

# %% [markdown]
# ### With fillna we replaced all the missing values with the name others.

# %%
df = df.dropna()                                 # df.dropna drops all the missing values

# %%
df.isnull().sum()
# Out:
# Name               0
# Brand              0
# Price              0
# DiscountedPrice    0
# Category           0
# SubCategory        0
# Quantity           0
# Description        0
# BreadCrumbs        0
# dtype: int64

# %% [markdown]
# ### As we can see after treating the missing values with fillna and dropna we can see there are no missing values in the dataset by using isnull.sum

# %% [markdown]
# ## Outlier detection

# %% [markdown]
# ### An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.

# %%
sns.boxplot(x = 'Price',data=df)            # sns.boxplot gives us the visualization of boxplot                
plt.show()

# %%
sns.boxplot(x='DiscountedPrice',data=df)
plt.show()

# %% [markdown]
# ### Here we can see there are few outliers in Price and DiscountedPrice columns

# %%
df['Price'].quantile([0.5,0.67,0.79,0.95,0.99])       # df.quantile gives the percentage of specific values
# Out:
# 0.50     175.00
# 0.67     266.00
# 0.79     399.00
# 0.95    1249.00
# 0.99    3104.75
# Name: Price, dtype: float64

# %%
df['Price'].max()                                    # df.max gives the maximum value of the column in a dataset
# Out:
# 10990.0

# %%
df['DiscountedPrice'].quantile([0.5,0.67,0.79,0.95,0.99])        # df.quantile gives the percentage of specific values
# Out:
# 0.50     125.00
# 0.67     195.00
# 0.79     284.99
# 0.95     849.00
# 0.99    2020.43
# Name: DiscountedPrice, dtype: float64

# %%
df['DiscountedPrice'].max()                           # df.max gives the maximum value of the column in a dataset
# Out:
# 7999.0

# %% [markdown]
# ### As we can see there is huge difference between 99 percentile and maximum value of the particular column, So by this we can surely say there are outliers in it.

# %% [markdown]
# ## Inter Quartile Range(IQR) Method

# %%
Q1=df['Price'].quantile(0.25)                  # df.quantile(0.25) gives the 25th percentile of a column
Q3=df['Price'].quantile(0.75)                  # df.quantile(0.75) gives the 75th percentile of a column
Q1,Q3
# Out:
# (85.0, 345.0)

# %%
IQR = Q3-Q1                                   # IQR = Difference between 75th percentile and 25th percentile
IQR
# Out:
# 260.0

# %%
lower_limit = Q1 - 1.5*IQR                   # Lower limit and Upper limit to display the dataset without outliers.
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (-305.0, 735.0)

# %%
df_no = df[(df['Price'] > lower_limit) & (df['Price'] < upper_limit)]     # we display the dataset without outliers
df_no
# Out:
#                                            Name    Brand  Price  \
# 0                        Premia Badam (Almonds)   Premia  451.0
# 1                        Premia Badam (Almonds)   Premia  109.0
# 2                        Premia Badam (Almonds)   Premia  202.0
# 3             Nutraj California Almonds (Badam)   Nutraj  599.0
# 5                                     Chana Dal   others   49.0
# ...                                         ...      ...    ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet   55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet   85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet   55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet  110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet   90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# ...

# %% [markdown]
# ### So after applying IQR formula we removed outliers and we displayed the datset with no outliers in Price Column

# %%
Q1=df['DiscountedPrice'].quantile(0.25)                     # df.quantile(0.25) gives the 25th percentile of a column
Q3=df['DiscountedPrice'].quantile(0.75)                     # df.quantile(0.75) gives the 75th percentile of a column
Q1,Q3
# Out:
# (64.0, 249.0)

# %%
IQR = Q3-Q1                                                 # IQR = Difference between 75th percentile and 25th percentile
IQR
# Out:
# 185.0

# %%
lower_limit1 = Q1 - 1.5*IQR                               # Lower limit and Upper limit to display the dataset without outliers.
upper_limit1 = Q3 + 1.5*IQR
lower_limit1,upper_limit1
# Out:
# (-213.5, 526.5)

# %%
df_no_1 = df[(df['DiscountedPrice'] > lower_limit) & (df['DiscountedPrice'] < upper_limit)]
df_no_1
# Out:
#                                            Name    Brand   Price  \
# 0                        Premia Badam (Almonds)   Premia   451.0
# 1                        Premia Badam (Almonds)   Premia   109.0
# 2                        Premia Badam (Almonds)   Premia   202.0
# 3             Nutraj California Almonds (Badam)   Nutraj   599.0
# 4             Nutraj California Almonds (Badam)   Nutraj  1549.0
# ...                                         ...      ...     ...
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet    55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet    85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet    55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet   110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet    90.0
#
#       DiscountedPrice         Category         SubCategory Quantity  \
# 0               329.0          Grocery  Grocery/Dry Fruits   500 gm
# ...

# %% [markdown]
# ### So after applying IQR formula we removed outliers and we displayed the datset with no outliers in DiscountedPrice Column

# %%
sns.boxplot(x='Price',data=df_no)                             # sns.boxplot gives us the visualization of boxplot 
plt.show()

# %%
sns.boxplot(x='DiscountedPrice',data=df_no_1)
plt.show()

# %% [markdown]
# ### Now we can clearly see by visualization there are no outliers present .

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Categorical Univariate Analysis

# %% [markdown]
# ## Countplot
#
# ### Countplot is basically a count of frequency plot in form of a bar graph. It plots the count of each category in a separate bar. When we use the pandas’ value counts function on any column, It is the same visual form of the value counts function.

# %% [markdown]
# ### Value counts gives the number of values in the choosen column,plot bar gives the bar graph of that and normalize function gives the percentage value,figsize adjusts the size of the plot

# %%
df['Category'].value_counts(normalize=True).plot.barh(figsize=[10,7])
plt.show()

# %% [markdown]
# ### By visualizing the countplot we have more products of Personal Care Category and less products of Smart Watches Category in Category Column

# %%
df['SubCategory'].value_counts(normalize=True).plot.barh(figsize=[10,15])
plt.show()

# %% [markdown]
# ### By visualizing the countplot we have more products of Snacks&Farsans and less products of Smart Watches  in SubCategory Column

# %%
df['Brand'].value_counts(normalize=True).plot.barh(figsize=[30,200])  # value counts gives the number of values in the choosen column
plt.show()

# %% [markdown]
# ### We filled the missing values by others in the Brand column if we visualize the countplot we have more products of unknown brands(i.e.,others) after that we have more products of Premia brand and less products of Candyman brand

# %%
df['Name'].value_counts().head(30).plot.barh(figsize=[10,7])   # plot.bar shows the bar graph of the selected column 
plt.show()

# %% [markdown]
# ### As Name column have many values I have taken some values by using head and visualized the bargraph in those values we have more number of products of a product named "Elle 18  Nail pops Nail colour "

# %% [markdown]
# ## Numerical Univariate Analysis

# %% [markdown]
# ## Histplot
#
# ### A histogram is a value distribution plot of numerical columns.we can have a look where more values lie like in positive, negative, or at the center(mean).

# %% [markdown]
# ### sns. histplot gives the distribution plot , kde = True gives us a KDE(Kernel Density Estimation) over histogram which explains PDF(Probability Density Function) which means what is the probability of each value occurring in this column.

# %%
sns.histplot(df_no_1['Price'],kde=True,linewidth=0) # sns.histplot gives the distribution plot,kde = True gives us a KDE(Kernel Density Estimation) over histogram
plt.show()

# %% [markdown]
# ### By observing the above histogram we can say that the Price of most of the products are between 0 to 500 rupees and there are very less products of higher price

# %%
sns.histplot(df_no_1['DiscountedPrice'],kde=True,linewidth=0) # sns.histplot gives the distribution plot,kde = True gives us a KDE(Kernel Density Estimation) over histogram
plt.show()

# %% [markdown]
# ### By observing the above histogram we can say that the DiscountedPrice of most of the products are between 0 to 150 rupees and there are very less products of higher Discountedprice

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Numerical - Numerical Analysis

# %% [markdown]
# ## Scatter Plot
#
# ### To plot the relationship between two numerical variables scatter plot is a simple plot to do.

# %%
sns.scatterplot(x="Price", y="DiscountedPrice",data=df_no_1)   # sns.scatterplot shows us the scatterplot
# Out:
# <AxesSubplot:xlabel='Price', ylabel='DiscountedPrice'>

# %% [markdown]
# ### By seeing this scatterplot we can say that the products with low price have low discounts and products with high price have high discounts

# %% [markdown]
# ## Numerical - Categorical Analysis

# %% [markdown]
# ## Bar Plot
#
# ### Bar plot is a simple plot which we can use to plot categorical variable on the x-axis and numerical variable on y-axis and explore the relationship between both variables. The blacktip on top of each bar shows the confidence Interval.

# %%
sns.barplot(x="Price", y="Category",data=df_no_1)        # sns.barplot shows us the barplot
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %% [markdown]
# ### By observing this barplot we can say that the price of Backpacks Category is very high when compared to others and the price of Fruits & Vegetables Category is low

# %%
sns.barplot(x="DiscountedPrice", y="Category",data=df_no_1)
# Out:
# <AxesSubplot:xlabel='DiscountedPrice', ylabel='Category'>

# %% [markdown]
# ### As we infered that when the price increases the discounted price also increase and by observing this barplot also we can say that the discounted price of Backpacks Category is very high when compared to others and the discounted price of Fruits & Vegetables Category is low

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="Price", y="SubCategory",data=df_no_1)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='SubCategory'>

# %% [markdown]
# ### By observing this barplot we can say that the price of Backpacks SubCategory is very high when compared to others and the price of Home & Kitchen/Tissue Paper & Napkins SubCategory is low

# %%
plt.figure(figsize=(15,15))
sns.barplot(x="DiscountedPrice", y="SubCategory",data=df_no_1)
# Out:
# <AxesSubplot:xlabel='DiscountedPrice', ylabel='SubCategory'>

# %% [markdown]
# ### By observing this barplot we can say that the discounted price of Backpacks SubCategory is very high when compared to others and the discounted price of Home & Kitchen/Tissue Paper & Napkins SubCategory is low

# %% [markdown]
# ## Distplot
#
# ### Distplot explains the PDF function using kernel density estimation

# %%
sns.distplot(df_no_1[df_no_1['Brand'] == 'Navneet']['Price'],kde=True,hist=False,color="blue") 
sns.distplot(df_no_1[df_no_1['Brand'] == 'Premia']['Price'],kde=True,hist=False,color="orange")
plt.show()

# %% [markdown]
# ### As we can see the graph is really very interesting. the blue one shows the price of brand Navneet and the orange plot shows the price of brand premia. If we observe it we can see that price of Navneet is higher than premia.

# %%
sns.distplot(df_no_1[df_no_1['Quantity'] == '500 gm']['Price'],kde=True,hist=False,color="blue") 
sns.distplot(df_no_1[df_no_1['Quantity'] == '200 gm']['Price'],kde=True,hist=False,color="orange")
plt.show()

# %% [markdown]
# ### As we can see the blue one shows the price of quantity 500 gm and the orange plot shows the price of quantity 200 gm. If we observe it we can see that price of quantities having 200 gm is higher than quantities having 500gm.

# %% [markdown]
# ## Categorical - Categorical Analysis

# %% [markdown]
# ##  Crosstab
#
#
# ### A crosstab is a table showing the relationship between two or more variables. Where the table only shows the relationship between two categorical variables, a crosstab is also known as a contingency table.

# %%
pd.crosstab(df_no_1['Category'], df_no_1['SubCategory'])
# Out:
# SubCategory             Appliances  Baby & Kids  Backpacks  Bakery  \
# Category
# Appliances                       8            0          0       0
# Baby & Kids                      0            4          0       0
# Backpacks                        0            0          2       0
# Beauty & Cosmetics               0            0          0       0
# Clothing & Accessories           0            0          0       0
# Computer Accessories             0            0          0       0
# DMart Grocery                    0            0          0       0
# Dairy & Beverages                0            0          0       0
# Fruits & Vegetables              0            0          0       0
# Geep                             0            0          0       0
# Grocery                          0            0          0       0
# Home & Kitchen                   0            0          0       0
# Joyo Plastics                    0            0          0       0
# ...

# %% [markdown]
# ## Heatmap
#
#
# ### A heatmap (or heat map) is a graphical representation of data where values are depicted by color.

# %%
sns.heatmap(pd.crosstab(df_no_1['Category'], df_no_1['SubCategory']),cmap='Reds')
# Out:
# <AxesSubplot:xlabel='SubCategory', ylabel='Category'>

# %% [markdown]
# ### By seeing this heatmap there is very less correlation between category and subcategory,Dmart grocery and Face care have higher correlation among them.

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Multivariate Analysis is defined as a process of involving multiple dependent variables resulting in one outcome. This explains that the majority of the problems in the real world are Multivariate

# %% [markdown]
# ## Pairplot

# %% [markdown]
# ### Plot pairwise relationships in a dataset. By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column.

# %%
sns.pairplot(df_no_1,hue='Category')
plt.show()

# %% [markdown]
# ### We can clearly see the relation between price,discounted price and brand it is linear.Price and discounted price is increases linearly.

# %%
plt.figure(figsize=(30,10))
sns.scatterplot(x='Price',y='DiscountedPrice',data=df_no_1,hue='SubCategory')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='DiscountedPrice'>

# %% [markdown]
# ### Price and discounted price is increases linearly and more number of subcategories price lies between 0 to 500 rupees

# %% [markdown]
# ## INSIGHTS

# %%
df.groupby(['Category','SubCategory','Brand'])['Brand'].count()
# Out:
# Category                       SubCategory                    Brand
# Appliances                     Appliances                     Ambrane        2
#                                                               Duracell       2
#                                                               Panasonic      2
#                                                               Zebronics      1
#                                                               others         1
#                                                                             ..
# Syska                          Syska                          Syska          1
# Tableware                      Tableware                      others        18
# Water Purifiers & Accessories  Water Purifiers & Accessories  others         1
# Wonderchef                     Wonderchef                     Wonderchef     1
# Zebronics                      Zebronics                      Zebronics      5
# ...

# %% [markdown]
# ### This is the list of Number of Brands in each category

# %%
clothing = df[df['Category']=='Clothing & Accessories']

# %%
clothing.SubCategory.value_counts()
# Out:
# Men's      50
# Women's    47
# Name: SubCategory, dtype: int64

# %%
clothing.groupby('SubCategory')['DiscountedPrice'].mean()
# Out:
# SubCategory
# Men's      204.260000
# Women's    276.914894
# Name: DiscountedPrice, dtype: float64

# %% [markdown]
# ### This outcome was obvious, as womens are more involved into clothes shoping so they are offereing more discount on women's Clothings

# %%
clothing[(clothing['SubCategory']=="Women's")&(clothing['DiscountedPrice']>300)]
# Out:
#                                                    Name     Brand  Price  \
# 4871    Clio Ladies T-Shirt & Pyjama Nightwear Set (A1)      Clio  475.0
# 4872    Clio Ladies T-Shirt & Pyjama Nightwear Set (A1)      Clio  475.0
# 4873    Clio Ladies T-Shirt & Pyjama Nightwear Set (A1)      Clio  475.0
# 4874    Clio Ladies T-Shirt & Pyjama Nightwear Set (A5)      Clio  475.0
# 4875    Clio Ladies T-Shirt & Pyjama Nightwear Set (A5)      Clio  475.0
# 4876    Clio Ladies T-Shirt & Pyjama Nightwear Set (A5)      Clio  475.0
# 4877    Clio Ladies T-Shirt & Pyjama Nightwear Set (A4)      Clio  475.0
# 4878    Clio Ladies T-Shirt & Pyjama Nightwear Set (A2)      Clio  475.0
# 4879    Clio Ladies T-Shirt & Pyjama Nightwear Set (A6)      Clio  475.0
# 4880    Clio Ladies T-Shirt & Pyjama Nightwear Set (A6)      Clio  475.0
# 4881    Clio Ladies T-Shirt & Pyjama Nightwear Set (A6)      Clio  475.0
# 4889  In Shape Ladies Inner Elastic Hipster Panties - C  In Shape  500.0
# ...

# %% [markdown]
# ### There are the products which have discounted price greater than 300 in womens clothing

# %%
df[df['Category']=='Personal Care'].groupby(['SubCategory','Brand'])['Name'].count().reset_index()
# Out:
#                 SubCategory       Brand  Name
# 0               Baby & Kids     Friends     4
# 1               Baby & Kids    Himalaya    11
# 2               Baby & Kids     Huggies     9
# 3               Baby & Kids   Johnson's     5
# 4               Baby & Kids    Little's     1
# ..                      ...         ...   ...
# 257               Skin Care      others     2
# 258  Tissue Paper & Napkins   Cleanplus     1
# 259  Tissue Paper & Napkins  Fresh Ones     1
# 260  Tissue Paper & Napkins     Origami     3
# 261  Tissue Paper & Napkins     Premier     2
#
# [262 rows x 3 columns]

# %%
df[df['Category']=='Personal Care'].groupby('SubCategory')[['Brand','Name']].nunique().sort_values(by='Name',ascending=False).rename(columns={'Name':'No.of.Products'})
# Out:
#                          Brand  No.of.Products
# SubCategory
# Skin Care                   55             177
# Personal Care/Lip Care       6             128
# Hair Care                   39             124
# Personal Care/Face Care     17             109
# Health & Wellness           47             104
# Personal Care/Nail Care      4              68
# Oral Care                   14              57
# Deos & Perfumes             13              53
# Baby & Kids                 10              47
# Face Care                   17              46
# Eye Makeup                   8              41
# Shaving Needs                4              40
# Personal Hygiene            11              33
# Personal Care/Skin Care      4              17
# Personal Care                6              16
# Tissue Paper & Napkins       4               6
# Lip Care                     3               4

# %% [markdown]
# ### These are the number of products and quantity in each brand of every subcategory, So as we can see the we have more number of skincare products and very less number of lip care products in the personal care category

# %%
df[df['Category']=='Personal Care'].groupby(['Price','Brand'])['Name'].count().reset_index().sort_values(by='Price',ascending=False)
# Out:
#       Price       Brand  Name
# 715  1999.0        Vega     1
# 714  1840.0    Gillette     1
# 713  1699.0        Olay     1
# 712  1649.0     Huggies     3
# 711  1649.0    Gillette     1
# ..      ...         ...   ...
# 4      22.0   Patanjali     1
# 3      22.0  Hansaplast     2
# 2      20.0       Vicks     2
# 1      18.0    Oraldent     1
# 0      10.0      Godrej     1
#
# [716 rows x 3 columns]

# %% [markdown]
# ### The costliest product in personal care category is from vega brand which is 1999 rupees and cheapest product is from godrej brand which is 10 rupees.

# %%
df[df['Category']=='Personal Care'].groupby(['DiscountedPrice','Brand'])['Name'].count().reset_index().sort_values(by='DiscountedPrice',ascending=False)
# Out:
#      DiscountedPrice       Brand  Name
# 874           1499.0    Gillette     1
# 873           1399.0        Vega     1
# 872           1390.0        Olay     1
# 871           1184.0    Gillette     1
# 870           1099.0     Huggies     2
# ..               ...         ...   ...
# 4               17.0  Hansaplast     1
# 3               17.0    Hand Aid     1
# 2               15.0  Hansaplast     1
# 1               10.0    Oraldent     1
# 0                9.0      Godrej     1
#
# [875 rows x 3 columns]

# %% [markdown]
# ### We can see the highest discount we are getting for the gillete brand and lowest discount for godrej brand, So we can conclude that our observation is correct that the price and discounted price are proportional
